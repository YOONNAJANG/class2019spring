# %% [markdown]
# # week 12
#
# ## 5/21
#
# # Boston housing

# %%
# description
# https://www.kaggle.com/c/boston-housing

# TensorFlow and tf.keras
import tensorflow
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation

# Helper libraries
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# train set과 test set 으로 케라스에서 불러온 보스턴 하우징 데이터를 나눈다.

# %%
(x_train, y_train), (x_test, y_test) = tensorflow.keras.datasets.boston_housing.load_data(path='boston_housing.npz')

# %% [markdown]
# parameter 수는 weight 를 나타내는 화살표(노드 간 연결)의 개수
#
# 입력은 13개의 노드, hidden layer의 노드 개수는 10, 출력은 1개의 노드
#
# 13*10 = 130 이 아니라 왜 140개의 parameter?
#
# 입력 13에 y = ax + b 에서 상수값을 나타내는 b를 더한 14개의 노드
#
# 따라서 input layer가 14개의 노드가 되고 14*10 = 140 개의 parameter가 되는 것

# %%
model = Sequential()
model.add(Dense(10, input_shape=[13], activation = 'relu'))
model.add(Dense(1))
model.compile(optimizer='rmsprop', loss='mse')
model.summary()
# Out:
# WARNING:tensorflow:From /Users/yoonna/anaconda3/envs/tensorflow/lib/python3.7/site-packages/tensorflow/python/ops/resource_variable_ops.py:435: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /Users/yoonna/anaconda3/envs/tensorflow/lib/python3.7/site-packages/tensorflow/python/keras/utils/losses_utils.py:170: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense (Dense)                (None, 10)                140
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 11
# ...
# Total params: 151
# Trainable params: 151
# ...

# %% [markdown]
# 입력과 출력의 모양?
#
# 입력은 13차원, 출력은 1차원
#
# None이라고 나오는 것은 1이라고 생각하면 됨.

# %%
print(model.input_shape)
print(model.output_shape)
# Out:
# (None, 13)
# (None, 1)

# %%
x_train.shape
# Out:
# (404, 13)

# %% [markdown]
# ### None = batch_size?
#
# 배치는 한 번에 처리하는 단위 수
#
# 효율적인 계산을 위해 일정 수 만큼 정해주고, 그 만큼씩 연산을 진행
#
# 배치를 따로 설정하지 않을 시, 기본 값은 32

# %%
model.fit(x_train, y_train, epochs=1000, batch_size = 64)
# Out:
# Epoch 1/1000
# 404/404 [==============================] - 0s 40us/sample - loss: 11.8313
# Epoch 2/1000
# 404/404 [==============================] - 0s 44us/sample - loss: 14.7056
# Epoch 3/1000
# 404/404 [==============================] - 0s 45us/sample - loss: 13.0999
# Epoch 4/1000
# 404/404 [==============================] - 0s 36us/sample - loss: 11.6711
# Epoch 5/1000
# 404/404 [==============================] - 0s 50us/sample - loss: 12.7673
# Epoch 6/1000
# 404/404 [==============================] - 0s 46us/sample - loss: 12.9697
# Epoch 7/1000
# 404/404 [==============================] - 0s 37us/sample - loss: 13.4812
# Epoch 8/1000
# 404/404 [==============================] - 0s 45us/sample - loss: 13.4066
# Epoch 9/1000
# 404/404 [==============================] - 0s 44us/sample - loss: 12.1083
# Epoch 10/1000
# 404/404 [==============================] - 0s 43us/sample - loss: 11.9972
# Epoch 11/1000
# ...

# %%
model.evaluate(x_test, y_test)
# Out:
# 102/102 [==============================] - 0s 115us/sample - loss: 33.2738
# 33.27375254911535

# %%
# INPUT::
# 1. crim: per capita crime rate by town.
# 2. zn: proportion of residential land zoned for lots over 25,000 sq.ft.
# 3. indus: proportion of non-retail business acres per town.
# 4. chas: Charles River dummy variable (= 1 if tract bounds river; 0 otherwise).
# 5. nox: nitrogen oxides concentration (parts per 10 million).
# 6. rm: average number of rooms per dwelling.
# 7. age: proportion of owner-occupied units built prior to 1940.
# 8. dis: weighted mean of distances to five Boston employment centres.
# 9. rad: index of accessibility to radial highways.
# 10. tax: full-value property-tax rate per $10,000.
# 11. ptratio: pupil-teacher ratio by town.
# 12. black: 1000(Bk - 0.63)^2 where Bk is the proportion of blacks by town.
# 13. lstat: lower status of the population (percent).

# TARGET::
# medv: median value of owner-occupied homes in $1000s.

boston_housing = ['crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age',
                  'dis', 'rad', 'tax', 'ptratio', 'black', 'lstat']

for i in range(13):
    plt.subplot(3,5,i+1)
    plt.plot(x_train[:,i], y_train, '.')
    plt.title(boston_housing[i])
plt.show()

# %% [markdown]
# ### make the highest price!
#
# 임의의 값을 넣을 때 위의 입력 shape과 동일하게 (1, 13) 으로 설정을 해 주어야 한다.
#
# 가장 높은 집값을 만들려면 어떤 요소들이 어떤 값을 지녀야 하는지 위의 그래프를 참고하여 임의로 넣어본 후 predict 해 보자.

# %%
model.predict(np.array([0, 90, 0, 1, 0, 
                        100, 0, 10, 0, 250, 
                        13, 300, 0]).reshape(1,13))
# Out:
# array([[332.8444]], dtype=float32)

# %% [markdown]
# ### make the lowest price!
#
# 마찬가지로 파라미터들의 값을 조정하여 가장 낮은 값을 예측하도록 만들어 보자.

# %%
model.predict(np.array([100, 10, 25, 0, 1, 
                        50, 100, 0, 25, 700, 
                        23, 0, 30]).reshape(1,13))
# Out:
# array([[120.28582]], dtype=float32)
